# %% [markdown]
# # Welcome
#
# <details>
# <summary><strong>Instructor Notes (Workshop Only)</strong></summary>
#
# - Welcome participants and introduce yourself.
# - Briefly introduce the **Graybill Statistics and Data Science Laboratory (Stat Lab)** and the research support services offered through **CSU Libraries**.
# - Invite any new participants to introduce themselves and share their research interests.
#
# </details>

# %% [markdown]
# # Starting With Data
#
# ## Objectives
#
# - Navigate the workshop directory and download a dataset.
# - Explain what a library is and what libraries are used for.
# - Describe what the Python Data Analysis Library (Pandas) is.
# - Load Pandas.
# - Read tabular data into Python using Pandas.
# - Describe what a DataFrame is in Python.
# - Access and summarize data stored in a DataFrame.
# - Define indexing as it relates to data structures.
# - Perform basic mathematical operations and summary statistics in a Pandas DataFrame.
# - Create simple plots.
#
# ## Questions
#
# - How can I import data in Python?
# - What is Pandas?
# - Why should I use Pandas to work with data?
#
# This Jupyter Notebook was based on [Starting With Data](https://datacarpentry.github.io/python-ecology-lesson/02-starting-with-data.html) and assembled with support from OpenAI. (2026). ChatGPT (July 1 version) [Large language model]. https://chat.openai.com/chat

# %% [markdown]
# ## Working With Pandas DataFrames in Python
#
# We can automate the process of performing data manipulations in Python. This makes our work reproducible and easy to share with others.
#
# ### Starting in the same spot
#
# For this lesson, navigate to the workshop directory before running the notebook. If you're using Jupyter Notebook, start the notebook in the workshop directory.
#
# ### Our data
#
# We will use a subset of the data from [Ernst et al. Long-term monitoring and experimental manipulation of a Chihuahuan Desert ecosystem near Portal, Arizona, USA.](https://www.esapubs.org/archive/ecol/E090/118/default.htm).
#
# **Dataset download:** https://ndownloader.figshare.com/files/2292172
#
# The data include observations of species and weight of animals caught in study sites.

# %% [markdown]
# ## About libraries
#
# A library in Python contains a set of tools (functions) that perform tasks on our data. Importing a library is like getting lab equipment out of storage and setting it up for use.
#
# ### Pandas in Python
#
# Pandas is one of the best options for working with tabular data in Python. It provides data structures, basic plotting, and integrates well other popular libraries like NumPy and Matplotlib.

# %%
# The following imports the pandas library with the alias 'pd' for easier access
import pandas as pd

# %% [markdown]
# ## Reading CSV Data Using Pandas
#
# CSV stands for Comma-Separated Values and is a common way to store tabular data. Pandas can read CSV files directly into a DataFrame using `read_csv()`.
#
# > **Student note:** This notebook expects `data/surveys.csv` to exist relative to the notebook location.

# %%
# Load the surveys data
surveys_df = pd.read_csv("data/surveys.csv")
surveys_df.head()

# %% [markdown]
# ### What is a DataFrame?
#
# A DataFrame is a 2-dimensional data structure that can store multiple data types in columns. It is similar to a spreadsheet or SQL table and always has an index.

# %%
type(surveys_df)

# %%
surveys_df.dtypes

# %% [markdown]
# ### Useful ways to view DataFrames
#
# Attributes are features of an object, such as `columns` and `shape`. Methods are actions, such as `head()` and `tail()`.

# %%
surveys_df.columns

# %%
surveys_df.shape

# %%
surveys_df.tail()

# %% [markdown]
# ## Check Your Understanding
#
# - What happened?
# - Did the output match your prediction?
#
# ## Challenge: Exploring Data
# Try the following on your own ```surveys_df.head()``` and adjust it so the first 15 rows appear

# %%
# Write your solution here

# %% [markdown]
# ## Calculating Statistics From Data in a Pandas DataFrame
#
# First, explore the column names and unique species.

# %%
surveys_df.columns

# %%
pd.unique(surveys_df['species_id'])

# %%
# Get all the stats
surveys_df['weight'].describe()

# %%
# Get individual stats
surveys_df['weight'].min()
surveys_df['weight'].max()
surveys_df['weight'].mean()
surveys_df['weight'].std()
surveys_df['weight'].count()

# %% [markdown]
# ### Challenge: Statistics
#
# - Create a list of unique site IDs using `plot_id`.
# - Count the plots.

# %%
# Write your solution here

# %% [markdown]
# ## Check Your Understanding
#
# - What did this section demonstrate?
# - What result would you expect if you changed the example?
#
# ## Exercise
# Execute the code in the next cell and observe the outcome.

# %%
site_names = pd.unique(surveys_df['plot_id'])
len(site_names)

# %% [markdown]
# ## Groups in Pandas
#
# We often want summary statistics grouped by subsets of a dataset, such as average weight by sex or site.

# %%
grouped_data = surveys_df.groupby('sex')

# %% [markdown]
# ## Check Your Understanding
#
# - What did this section demonstrate?
# - What result would you expect if you changed the example?
#
# ## Exercise
# Try modifying the code in the next cell and observe the outcome.

# %%
grouped_data.mean(numeric_only=True)

# %% [markdown]
# ### Challenge: Summary Data
#
# - How many recorded individuals are female and how many male?
# - What happens when grouping by plot and sex? ```grouped_data2 = surveys_df.groupby(['plot_id', 'sex'])```
# - Summarize weight values for each site.

# %%
# Write your solution here

# %% [markdown]
# ## Exercise
# Try modifying the code in the next cell and observe the outcome.

# %%
surveys_df.groupby('plot_id')['weight'].describe()

# %%
species_counts = surveys_df.groupby('species_id')['record_id'].count()
species_counts

# %% [markdown]
# ## Basic Math Functions
#
# We can apply mathematical operations to entire columns, such as multiplying all weights by 2. These can be displayed or saved to a new column

# %%
surveys_df['weight'] * 2

# %% [markdown]
# ## Plotting Data Using Pandas
#
# Pandas can create plots directly from DataFrames. In Jupyter, use Matplotlib inline to display them.

# %% [markdown]
# ## Exercise
# Try modifying the code in the next cell and observe the outcome.

# %%
# %matplotlib inline
species_counts.plot(kind='bar');

# %%
total_count = surveys_df.groupby('plot_id')['record_id'].nunique()
total_count.plot(kind='bar');

# %% [markdown]
# ### Challenge: Plots
#
# 1. Create a plot of average weight across all species per site.
# 2. Create a plot of total males versus total females for the entire dataset.

# %%
# Write your solution here

# %% [markdown]
# ## Exercise
# Try modifying the code in the next cell and observe the outcome.

# %%
surveys_df.groupby('plot_id').mean(numeric_only=True)['weight'].plot(kind='bar');

# %%
surveys_df.groupby('sex').count()['record_id'].plot(kind='bar');

# %% [markdown]
# ### Summary plotting challenge
#
# Create a stacked bar plot with weight on the y-axis and sex as the stacked variable.

# %%
by_site_sex = surveys_df.groupby(['plot_id', 'sex'])
site_sex_count = by_site_sex['weight'].sum()
spc = site_sex_count.unstack()
s_plot = spc.plot(kind='bar', stacked=True, title='Total weight by site and sex')
s_plot.set_ylabel('Weight')
s_plot.set_xlabel('Plot');

# %% [markdown]
# # Workshop Summary
#
# Congratulations!
#
# In this lesson you learned how to:
#
# - Libraries enable us to extend the functionality of Python.
# - Pandas is a popular library for working with data.
# - A DataFrame is a Pandas data structure that allows access by row or column.
# - Aggregating data with `groupby()` enables useful summaries quickly.
# - Plots can be created from DataFrames or grouped subsets.
#
# Continue experimenting by modifying examples in this notebook.

# %% [markdown]
# # Additional Resources
#
# Learning Python is a journey. The exercises in this notebook are just the beginning! To continue building your skills, explore the Python resources curated by the **[CSU Libraries Coding Support Hub](https://geospatialcentroid.github.io/coding-support/python/)**.
#
# ---
#
# ### Need Help?
#
# If you get stuck, don't give up! There are many ways to get help:
#
# - Review the examples in this notebook.
# - Search the Coding Support Hub for tutorials and answers.
# - Use an AI coding assistant to help explain concepts and debug your code.
# - Make a [Coding Support Request](https://geospatialcentroid.github.io/coding-support/support-request/)
